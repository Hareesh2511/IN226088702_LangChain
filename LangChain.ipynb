# %% [markdown]
# **Install & Imports**

# %%
# !pip install -U langchain langchain-core langchain-community langchain-openai openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 3.2 MB/s eta 0:00:00
# ...

# %%
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

# %% [markdown]
# **LLM Setup**

# %%
llm = ChatOpenAI(
    model="gpt-3.5-turbo",
    temperature=0.7,
    openai_api_key="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"
)

# %% [markdown]
# **Prompt Template**

# %%
prompt = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms"
)

# %% [markdown]
# **Chain (Prompt → LLM → Output)**

# %%
chain = prompt | llm | StrOutputParser()

# %% [markdown]
# **Tool (Custom Function)**

# %%
def calculator_tool(query):
    return "This is a simple calculator tool (demo output -->  4)"

tools = {
    "calculator": calculator_tool
}

# %% [markdown]
# **Agent Logic**

# %%
def agent(user_input):

    # If user asks calculation → use tool
    if "calculate" in user_input:
        return tools["calculator"](user_input)

    # Otherwise → use LLM chain
    return chain.invoke({"topic": user_input})

# %% [markdown]
# **Full Pipeline Execution**

# %%
user_input = input("Enter your query: ")

output = agent(user_input)

print("\nFinal Output:")
print(output)
# Out:
# Enter your query: calculate 2+2
#
# Final Output:
# This is a simple calculator tool (demo output -->  4)

# %% [markdown]
# **Pipeline Mapping**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
